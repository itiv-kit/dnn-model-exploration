# %%
import pandas as pd

file = '../results.csv'

df = pd.read_csv(file)

df.head()
# Out:
#    Unnamed: 0  LayerIdx    LayerType       Energy                      Reads  \
# 0           0         0  QuantConv2d  698969600.0  [   3456 3709440       0]
# 1           1         1  QuantConv2d  658739200.0  [  18432 4930560       0]
# 2           2         2  QuantConv2d  245964800.0  [   2048 1638400       0]
# 3           3         3  QuantConv2d  163942400.0     [  1024 819200      0]
# 4           4         4  QuantConv2d  331673600.0  [   9216 2488320       0]
#
#                      Updates  BitsInp  BitsW  \
# 0  [      0       0 3276800]        8      8
# 1  [      0       0 1638400]        8      8
# 2     [     0      0 819200]        8      8
# 3     [     0      0 819200]        8      8
# 4     [     0      0 819200]        8      8
#
#                              Workload_Size
# 0  [320, 320, 12, 1, 32, 3, 3, 1, 1, 1, 1]
# 1  [320, 320, 32, 1, 64, 3, 3, 1, 1, 2, 2]
# 2  [160, 160, 64, 1, 32, 1, 1, 0, 0, 1, 1]
# 3  [160, 160, 32, 1, 32, 1, 1, 0, 0, 1, 1]
# ...
